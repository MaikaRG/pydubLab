# %% [markdown]
# ## TODO's
#
# - Record an audio file of the following sentence "Hello, my name is <your_name_here>"
# - Open the file using pydub
# - Apply a low-pass `Butterworth` digital filter (the order of the filter doesn't matter). Choose different `Wn` also known as cuttoff frequency and plot the signal `filtered` and `unfiltered`. Use `filtfilt`.
# - Do the same with a high-pass filter (read the docs 😼)
# - Explain the visual differences of the high-pass and low-pass filter on the filtered signal.
# - Choose `butter` filter parameters to save an `mp3` audio file of your recording that resembles to be recorded from a phone call
#
# ## How to deliver the project
#
# - Deliver your code in following folder as a PR: `module2/lab-pydub-filter`
#
# ## Links & Resources
#
# - https://github.com/jiaaro/pydub
# - https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.signal.butter.html
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.filtfilt.html

# %%
import ffprobe
from ffprobe import FFProbe
import requests
import numpy as np
import scipy.signal as sg
import pydub
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from pydub import AudioSegment
import array
# %matplotlib inline

# %%
sonido = AudioSegment.from_mp3("yo.mp3")

# %%
yo = sonido.get_array_of_samples()

# %%
plt.plot(yo)
plt.show()

# %%
b, a = signal.butter(4, 100, 'low', analog=True)

# %%
low= sg.filtfilt(b, a, yo)
low =list(map(int, list(low)))
low_pass=array.array('h')
low_pass.fromlist(low)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-092fd0115bff> in <module>
#       1 low= sg.filtfilt(b, a, yo)
# ----> 2 low =list(map(int, list(low)))
#       3 low_pass=array.array('h')
#       4 low_pass.fromlist(low)
#
# ValueError: cannot convert float NaN to integer

# %%
plt.plot(low_pass)
plt.show()

# %%
yoLow = sonido._spawn(low_pass)

# %%
yoLow
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
b, a = signal.butter(3, .1, btype='high')

# %%
high= sg.filtfilt(b, a, yo)
high =list(map(int, list(high)))
high_pass=array.array('h')
high_pass.fromlist(high)

# %%
plt.plot(high_pass)
plt.show()

# %%
yoHigh = sonido._spawn(high_pass)

# %%
yoHigh
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
b, a = signal.butter(3, .1, btype='high', analog=False)
high= sg.filtfilt(b, a, yo)
high =list(map(int, list(high)))
high_pass=array.array('h')
high_pass.fromlist(high)
yoTelef = sonido._spawn(high_pass)
yoTelef
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
